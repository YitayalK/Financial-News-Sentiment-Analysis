# %%
import yfinance as yf
import pandas as pd
import numpy as np
from textblob import TextBlob

# Define the ticker and the time period
ticker = 'AAPL'
start_date = '2020-01-01'
end_date = '2023-01-01'

# Fetch the stock data
aapl_data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_data.head()
# Out:
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2020-01-02  72.796013  75.087502  75.150002  73.797501  74.059998  135480400
# 2020-01-03  72.088295  74.357498  75.144997  74.125000  74.287498  146322800
# 2020-01-06  72.662720  74.949997  74.989998  73.187500  73.447502  118387200
# 2020-01-07  72.320984  74.597504  75.224998  74.370003  74.959999  108872000
# 2020-01-08  73.484352  75.797501  76.110001  74.290001  74.290001  132079200

# %%
aapl_data.columns = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

aapl_data.columns
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
# Create a DataFrame with dates from the AAPL data
dates = aapl_data.index
text_data = pd.DataFrame(dates, columns=['Date'])

# %%
# Generate random headlines
headline_samples = [
    "AAPL hits record high",
    "Concerns over AAPL's future growth",
    "AAPL to unveil new product next month",
    "AAPL reports earnings that exceed forecasts",
    "Market downturn affects AAPL",
    "AAPL invests in renewable energy",
    "New AAPL CEO announced",
    "AAPL faces regulatory scrutiny",
    "AAPL rumored to acquire a tech startup",
    "AAPL's market share grows"
]

# Assign a random headline to each date
text_data['Headline'] = np.random.choice(headline_samples, size=len(text_data))

# Display the first few rows of the updated DataFrame
text_data.head()
# Out:
#         Date                               Headline
# 0 2020-01-02  AAPL to unveil new product next month
# 1 2020-01-03       AAPL invests in renewable energy
# 2 2020-01-06         AAPL faces regulatory scrutiny
# 3 2020-01-07           Market downturn affects AAPL
# 4 2020-01-08              AAPL's market share grows

# %%
text_data.head(30)
# Out:
#          Date                                     Headline  Sentiment
# 0  2020-01-02        AAPL to unveil new product next month   0.068182
# 1  2020-01-03             AAPL invests in renewable energy   0.000000
# 2  2020-01-06               AAPL faces regulatory scrutiny   0.000000
# 3  2020-01-07                 Market downturn affects AAPL   0.000000
# 4  2020-01-08                    AAPL's market share grows   0.000000
# 5  2020-01-09                       New AAPL CEO announced   0.136364
# 6  2020-01-10                       New AAPL CEO announced   0.136364
# 7  2020-01-13        AAPL to unveil new product next month   0.068182
# 8  2020-01-14  AAPL reports earnings that exceed forecasts   0.000000
# 9  2020-01-15                 Market downturn affects AAPL   0.000000
# 10 2020-01-16        AAPL to unveil new product next month   0.068182
# 11 2020-01-17               AAPL faces regulatory scrutiny   0.000000
# 12 2020-01-21             AAPL invests in renewable energy   0.000000
# 13 2020-01-22                        AAPL hits record high   0.160000
# 14 2020-01-23             AAPL invests in renewable energy   0.000000
# 15 2020-01-24                 Market downturn affects AAPL   0.000000
# 16 2020-01-27                    AAPL's market share grows   0.000000
# 17 2020-01-28           Concerns over AAPL's future growth   0.000000
# 18 2020-01-29             AAPL invests in renewable energy   0.000000
# 19 2020-01-30                 Market downturn affects AAPL   0.000000
# 20 2020-01-31                        AAPL hits record high   0.160000
# 21 2020-02-03        AAPL to unveil new product next month   0.068182
# 22 2020-02-04       AAPL rumored to acquire a tech startup   0.000000
# 23 2020-02-05             AAPL invests in renewable energy   0.000000
# 24 2020-02-06                        AAPL hits record high   0.160000
# 25 2020-02-07             AAPL invests in renewable energy   0.000000
# 26 2020-02-10       AAPL rumored to acquire a tech startup   0.000000
# 27 2020-02-11           Concerns over AAPL's future growth   0.000000
# 28 2020-02-12                        AAPL hits record high   0.160000
# 29 2020-02-13             AAPL invests in renewable energy   0.000000

# %%
def calculate_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Applying the sentiment analysis function to your headlines
text_data['Sentiment'] = text_data['Headline'].apply(calculate_sentiment)

# %%
text_data.head()
# Out:
#         Date                               Headline  Sentiment
# 0 2020-01-02  AAPL to unveil new product next month   0.068182
# 1 2020-01-03       AAPL invests in renewable energy   0.000000
# 2 2020-01-06         AAPL faces regulatory scrutiny   0.000000
# 3 2020-01-07           Market downturn affects AAPL   0.000000
# 4 2020-01-08              AAPL's market share grows   0.000000

# %%
# Aligning sentiment scores with the stock closing prices on the same date
combined_data = text_data.set_index('Date').join(aapl_data['Close'])
combined_data.head()
# Out:
#                                          Headline  Sentiment      Close
# Date
# 2020-01-02  AAPL to unveil new product next month   0.068182  75.087502
# 2020-01-03       AAPL invests in renewable energy   0.000000  74.357498
# 2020-01-06         AAPL faces regulatory scrutiny   0.000000  74.949997
# 2020-01-07           Market downturn affects AAPL   0.000000  74.597504
# 2020-01-08              AAPL's market share grows   0.000000  75.797501

# %%
combined_data['Daily Returns'] = combined_data['Close'].pct_change()

# %%
combined_data.head()
# Out:
#                                          Headline  Sentiment      Close  \
# Date
# 2020-01-02  AAPL to unveil new product next month   0.068182  75.087502
# 2020-01-03       AAPL invests in renewable energy   0.000000  74.357498
# 2020-01-06         AAPL faces regulatory scrutiny   0.000000  74.949997
# 2020-01-07           Market downturn affects AAPL   0.000000  74.597504
# 2020-01-08              AAPL's market share grows   0.000000  75.797501
#
#             Daily Returns
# Date
# 2020-01-02            NaN
# 2020-01-03      -0.009722
# 2020-01-06       0.007968
# 2020-01-07      -0.004703
# 2020-01-08       0.016086

# %%
correlation = combined_data['Sentiment'].corr(combined_data['Daily Returns'])
print("Correlation between sentiment and daily stock returns:", correlation)
# Out:
# Correlation between sentiment and daily stock returns: 0.0024608839113656527

# %%
correlation = combined_data['Sentiment'].corr(combined_data['Close'])
print("Correlation between sentiment and closing:", correlation)
# Out:
# Correlation between sentiment and closing: 0.03911582497448469
